# %% [markdown]
# Title: Simulating Income Distributions
# Author: Thomas M. Breuel

# %%
from pylab import *
from urllib2 import urlopen
from bisect import bisect

# %% [markdown]
# # Income Distributions and Political Debates

# %%
imshow(imread(urlopen("http://imgick.cleveland.com/home/cleve-media/width620/img/datacentral/photo/13425050-mmmain.png")))

# %% [markdown]
# # Reading the Income Distribution

# %%
data = genfromtxt("usincome.csv",skip_header=2,delimiter=",",names="lo,hi,n,mean,stddev")
for i in range(5): print data[i]
# Out:
# (0.0, 4999.0, 4245.0, 1249.0, 50.0)
# (5000.0, 9999.0, 5128.0, 7923.0, 30.0)
# (10000.0, 14999.0, 7149.0, 12389.0, 28.0)
# (15000.0, 19999.0, 7370.0, 17278.0, 26.0)
# (20000.0, 24999.0, 7037.0, 22162.0, 27.0)

# %%
data = array([list(x) for x in data])

# %%
plot(data[:,2])

# %%
idist = concatenate([data[:-2,2],[data[-2,2]/10]*10,[data[-1,2]/50]*50])

# %%
plot(idist)

# %% [markdown]
# # Random Samples from the Income Distribution

# %%
cdist = add.accumulate(idist)
cdist = cdist*1.0/amax(cdist)
plot(cdist)

# %%
bisect(cdist,rand())
# Out:
# 4

# %%
def empsample(dist,n=1):
    """Given an array representing a histogram, return a random bin number
    according to that histogram."""
    cdist = add.accumulate(dist)
    cdist = cdist*1.0/amax(cdist)
    result = [bisect(cdist,rand()) for i in range(n)]
    if n==1: return result[0]
    else: return array(result,'f')

# %% [markdown]
# Let's generate a population of 100000 individuals and their incomes.

# %%
N = 100000
incomes = 5000*(empsample(idist,n=N)+rand(100000))

# %% [markdown]
# The income statistics match what they should be pretty well. We ought to check this because we had to guess in the construction of the histogram at the top end.

# %%
print mean(incomes)
print median(incomes)
# Out:
# 67365.8728136
# 49416.0884012

# %%
_=hist(incomes,bins=200)

# %% [markdown]
# # Lorenz Curve and Gini Coefficient

# %% [markdown]
# Usually, what we look at in order to measure inequality is the _Gini index_.
#
# This is defined in terms of the Lorenz curve.
#
# The Lorenz curve gives the cumulative fraction of the total wealth/income of all the individuals at the given income rank or below.
#
# That is, we sort the individuals by income, accumulate the incomes, and normalize by the total.

# %%
lorenz_curve = add.accumulate(sorted(incomes))
lorenz_curve /= amax(lorenz_curve)
plot(lorenz_curve)

# %% [markdown]
# If everybody makes about the same income, the Lorenz curve is a straight line.

# %%
uniform_lorenz = add.accumulate(sorted(66000.0+0.0001*rand(100000)))
uniform_lorenz /= amax(uniform_lorenz)
plot(lorenz_curve)
plot(uniform_lorenz)

# %% [markdown]
# The Gini index is defined as a ratio of the areas on the Lorenz curve diagram. If the area between the line of perfect equality and the Lorenz curve is A, and the area under the Lorenz curve is B, then the Gini index is A / (A + B). Since A + B = 0.5, the Gini index is G = 2 * A or G = 1 – 2 B.

# %%
gini = 2*sum(linspace(0.0,1.0,len(lorenz_curve))-lorenz_curve)/len(lorenz_curve)
print gini
# Out:
# 0.464540573461

# %% [markdown]
# That's about right; the US Gini coefficient in 2007 was 0.45.

# %%
def gini(samples):
    lorenz_curve = add.accumulate(1.0*numpy.sort(samples))
    lorenz_curve /= amax(lorenz_curve)
    return 2*sum(linspace(0.0,1.0,len(lorenz_curve))-lorenz_curve)/len(lorenz_curve)

# %%
gini(incomes)
# Out:
# 0.46454057346112759

# %% [markdown]
# # Parametric Income Distributions

# %% [markdown]
# Let's look at the income distribution again.

# %%
_=hist(incomes,bins=100)

# %% [markdown]
# Can we match this with a parametric distribution?

# %% [markdown]
# The uniform distribution doesn't work; its shape is all wrong.

# %%
uincomes = rand(N)*2*mean(incomes)
_=hist(uincomes,bins=100)

# %% [markdown]
# It produces a variance and a Gini coefficient that are too small.
# We can't even reproduce the US income with that.

# %%
print var(uincomes)**.5
print gini(uincomes)
# Out:
# 39039.679575
# 0.333959740099

# %%
print mean(incomes)
print median(incomes)
print var(incomes)**.5
# Out:
# 67515.5161815
# 49491.1779127
# 66813.9394719

# %% [markdown]
# It turns out that the log-normal distribution is a fairly good match for income distributions, except at the high end, where it produces too many outliers.
#
# Log-normal distribution:
#
# $X = e^{\mu+\sigma Z}$

# %% [markdown]
# We want to match the parameters of the log-normal distribution to the actual parameters of the US income distribution. We can do that using these formulas.
#
# mean: $e^{\mu+\sigma^2/2}$
#
# median: $e^\mu$
#
# variance: $(e^{\sigma^2}-1) ~ e^{2\mu+\sigma^2}$
#
# We cap incomes at USD 1m to avoid the outliers.

# %%
mu = 10.8
sigma = 0.82
lnincomes = minimum(1e6,exp(randn(1000000)*sigma+mu))

# %%
_=hist(lnincomes,bins=100)

# %%
print mean(lnincomes)
print median(lnincomes)
print var(lnincomes)**.5
print gini(lnincomes)
# Out:
# 68603.6941199
# 48999.7501839
# 66632.4781507
# 0.437781413336

# %% [markdown]
# Why log-normal?
#
# - normal distribution from central limit theorem
# - large number of independent additive contributions
# - log-normal distribution also from central limit theorem
# - large number of independent _factors_
#
# $$ r = \prod_i (1+\epsilon_i) $$
#
# Log-normal tails are different from actual income distribution, but accounts for about 99% of incomes.

# %% [markdown]
# # Age Distribution

# %%
data = genfromtxt("usage.csv",skip_header=2,delimiter=",",names="lo,both,m,f")
for i in range(5): print data[i]
# Out:
# (0.0, 21434.0, 10955.0, 10479.0)
# (5.0, 20785.0, 10624.0, 10162.0)
# (10.0, 19893.0, 10178.0, 9714.0)
# (15.0, 21086.0, 10719.0, 10367.0)
# (20.0, 21154.0, 10684.0, 10470.0)

# %%
adist = [row[1] for row in data]
adist /= sum(adist)
plot(adist)

# %%
ages = (empsample(adist,n=N)+rand(N))*5.0
_=hist(ages,bins=100)

# %% [markdown]
# # Gini Index with Equal Starting Conditions and Growth

# %% [markdown]
# Let's look at the Gini coefficient of income distributions in the presence of growth.
#
# - everybody starts with the same income
# - everybody gets the same raise every year

# %%
gincomes = 21000*1.02**ages
print mean(gincomes)
print gini(gincomes)
_=hist(20000*1.02**ages,bins=100)
# Out:
# 48707.6178719
# 0.256541520039

# %%
gincomes = 10000*1.04**ages
print mean(gincomes)
print gini(gincomes)
_=hist(gincomes,bins=100)
# Out:
# 64262.986403
# 0.475625162875

# %%
gincomes = 15000*1.05**minimum(ages,60.0)
print mean(gincomes)
print gini(gincomes)
_=hist(gincomes,bins=100)
# Out:
# 124030.857176
# 0.435726093158

# %% [markdown]
# US historical GDP rate:
#
# 1950: USD 293.7b, population: 151m
#
# 2010: USD 14498b, population: 308m

# %%
100*((14498/293.7)**(1.0/60)-1.0)
# Out:
# 6.714492285404083

# %%
gincomes = 3000*1.07**minimum(ages,60.0)
print mean(gincomes)
print gini(gincomes)
_=hist(gincomes,bins=100)
# Out:
# 65355.6737054
# 0.53052393153

# %% [markdown]
# (Equality and Fairness)
#
# - everybody started out with the same income
# - everybody was subject to the same growth rate
#
# Is this fair? Should older workers get more money due to growth?
#
# Income growth itself is usually considered fair, but it produces inequality.

# %% [markdown]
# (Economics and Social Sciences View)
#
# This model is similar to a "random walk" model used in economics; economists usually are looking for more complicated explanations:
#
# - it may not exactly describe the tails of the distribution
# - economists and social scientists prefer theories involving actual choice and behavior

# %% [markdown]
# (Important Conclusion)
#
# Large differences in Gini coefficients can result from simple differences in overall economic success.
#
# Differences in Gini coefficients between societies/groups do not imply lack of fairness or equal treatment.
#
# Low growth rates imply lower Gini coefficients in simple economies.

# %% [markdown]
# # Gini Coefficients in Variable Economies

# %% [markdown]
# An additional source of variation could be that growth rates are themselves variable over time, as the economy undergoes busts and booms.

# %%
from scipy.ndimage import filters

def ecycles(target=4.0,sd=8.0,smooth=3.0,n=100):
    rates = randn(n)*sd+target
    rates = filters.gaussian_filter(rates,smooth)
    rates += target-mean(rates)
    return rates

# %%
rates = ecycles(n=200)
plot(rates)
print mean(rates)
# Out:
# 4.0

# %% [markdown]
# For the simulation, things now get trickier, since we actually need to keep track of populations over time, aging, etc.
# This is actually turning into _agent based modeling_.
# Each agent has a number of variables:
#
# - a lifetime
# - an age
# - a current income
#
# In an OOL, we might actually make each individual an object, but in an array language, we can also write this naturally using array.
#
# Furthermore, we start the simulation up with everbody at the same age, but then let the population equillibrate over time.

# %%
def random_lifetimes(N=N):
    return (empsample(adist,n=N)+rand(N))*5.0

# %%
starting_income = 10000.0
lifetimes = random_lifetimes()
ages = zeros(N)
incomes = starting_income*ones(N)

# %%
for y,g in enumerate(rates):
    die = find(ages>lifetimes)
    ages[die] = 0
    lifetimes[die] = random_lifetimes(len(die))
    incomes[die] = starting_income
    incomes *= 1.0+g/100.0
    ages += 1

# %%
incomes
# Out:
# array([ 10870.80487432,  34989.01782071,  36043.5725835 , ...,
#         24191.49442656,  19465.92117334,  12600.65577943])

# %%
_=hist(incomes,bins=30)
print gini(incomes)
# Out:
# 0.309836361361

# %%
def experiment(target=2.0,smooth=3.0,sd=8.0,n=200):
    rates = ecycles(target=target,smooth=smooth,sd=sd,n=n)
    starting_income = 10000.0
    lifetimes = random_lifetimes()
    ages = zeros(N)
    incomes = starting_income*ones(N)
    for y,g in enumerate(rates):
        die = find(ages>lifetimes)
        ages[die] = 0
        lifetimes[die] = random_lifetimes(len(die))
        incomes[die] = starting_income
        incomes *= 1.0+g/100.0
        ages += 1
    return gini(incomes)

# %%
ginihv = []
for i in range(200): 
    ginihv += [experiment(target=4.0,sd=8.0)]
    print i,ginihv[-1]

ginilv = []
for i in range(200): 
    ginilv += [experiment(target=4.0,sd=8.0)]
    print i,ginilv[-1]
# Out:
# 0 0.417282419926
# 1
#  0.565854112697
# 2
#  0.349942669322
# 3
#  0.453381141137
# 4
#  0.485416739977
# 5
#  0.382896225213
# 6
#  0.396119942682
# 7
#  0.399335564084
# 8
#  0.515478321702
# 9
#  0.538088371324
# 10
#  0.386561517856
# 11
#  0.239215297202
# 12
#  0.408202542839
# 13
#  0.463075979746
# 14
#  0.573346662421
# 15
#  0.375829949174
# 16
#  0.445780790948
# 17
#  0.443048954791
# 18
#  0.408556194028
# 19
#  0.261158424173
# 20
#  0.413365236483
# 21
#  0.537229597653
# 22
#  0.405834143138
# 23
#  0.53469247132
# 24
#  0.313526564341
# 25
#  0.306677842797
# 26
#  0.473078602053
# 27
#  0.515197475543
# 28
#  0.478418363041
# 29
#  0.479443663663
# 30
#  0.417324886071
# 31
#  0.473949968719
# 32
#  0.497800303296
# 33
#  0.440934146728
# 34
#  0.497617538188
# 35
#  0.515399896897
# 36
#  0.39814573139
# 37
#  0.412692394421
# 38
#  0.409729074872
# 39
#  0.558751069745
# 40
#  0.482404686171
# 41
#  0.423999668206
# 42
#  0.467725209358
# 43
#  0.397615340789
# ...

# %%
_=hist([ginilv,ginihv])
print mean(ginilv),mean(ginihv)
# Out:
# 0.434198721774 0.433194689808

# %% [markdown]
# Observations:
#
# - Gini indexes have high variance in both cases
# - this means that differences in Gini index for countries with different economic histories may not be meaningful
# - there is (surprisingly) no significant difference in average Gini index
#
# Note that the result might be different if we compare correlated economic histories (one is a smoothed version of the other).

# %%
def experiment2(rates,target=2.0,smooth=3.0,sd=8.0,n=200):
    starting_income = 10000.0
    lifetimes = random_lifetimes()
    ages = zeros(N)
    incomes = starting_income*ones(N)
    for y,g in enumerate(rates):
        die = find(ages>lifetimes)
        ages[die] = 0
        lifetimes[die] = random_lifetimes(len(die))
        incomes[die] = starting_income
        incomes *= 1.0+g/100.0
        ages += 1
    return gini(incomes)

# %%
deltas = []

for i in range(100):
    rates = ecycles(target=4.0,smooth=1.0,sd=8.0)
    rates2 = filters.gaussian_filter(rates,5.0)
    rates2 += 4.0-mean(rates2)
    if 0: plot(rates); plot(rates2); break
    g = experiment2(rates)
    g2 = experiment2(rates2)
    print i,g,g2,g-g2
    deltas.append(g-g2)
# Out:
# 0 0.429530156161 0.426108803753 0.00342135240795
# 1
#  0.416883158429 0.435602635715 -0.0187194772854
# 2
#  0.363350670752 0.37551705938 -0.0121663886277
# 3
#  0.456682426852 0.468749571427 -0.0120671445752
# 4
#  0.408830202814 0.413244304342 -0.00441410152799
# 5
#  0.476846350033 0.479021410205 -0.00217506017181
# 6
#  0.402496871153 0.410683899328 -0.00818702817467
# 7
#  0.394250612025 0.392305098866 0.00194551315862
# 8
#  0.423073492345 0.427007154164 -0.00393366181829
# 9
#  0.507429286749 0.509260929444 -0.00183164269504
# 10
#  0.498136635464 0.497680776418 0.000455859046032
# 11
#  0.487712845515 0.482420348638 0.005292496877
# 12
#  0.389409352303 0.405544324195 -0.0161349718926
# 13
#  0.35015256197 0.362847503219 -0.0126949412493
# 14
#  0.334905579496 0.352223681837 -0.0173181023413
# 15
#  0.417693419981 0.424230408763 -0.00653698878156
# 16
#  0.439482852716 0.443731147044 -0.00424829432723
# 17
#  0.478371771932 0.480549728353 -0.00217795642118
# 18
# ...

# %% [markdown]
# # Competitive Economies

# %% [markdown]
# Let's look at a completely different economic model.
#
# - Here, everybody starts out with the same starting capital (USD 10000).
# - People have slightly different skills at multiplying that capital, a normal distribution with a small spread.
# - They now exist in a competitive environment, where the return on investment is proportional to their skill.
# - Overall growth of the economy is limited to an annual 4%.
# - Note that this limit is usually achieved through a combination of inflation and other mechanisms.

# %%
wealth = 10000.0 * ones(N)
global_growth = 0.04
skill = maximum(1.01,1.04+0.01*randn(N))

gs = []
for i in range(100):
    rgrowth = (1.0-skill)*wealth
    growth = global_growth*sum(wealth)*rgrowth/sum(rgrowth)
    wealth += growth
    gs.append(gini(wealth))
    
plot(gs)

# %% [markdown]
# Here we see that slight differences in starting conditions (skills) produce great differences in wealth over the long term.

# %%
_=hist(skill,bins=200,range=(0,1.5))

# %% [markdown]
# (Fairness)
#
# - Is the resulting inequality "fair"?
# - Regardless of whether it is fair or not, very high inequality may cause problems.
# - What would be "fair" solutions to limiting inequality?

# %% [markdown]
# # Exercises

# %% [markdown]
# ## US vs German Differences

# %% [markdown]
# Can differences in Gini index between Germany and the US be explained by different growth rates and age distributions?
#
# - find German income distribution and age distribution data
# - compute average German growth over the last 60 years
#
# Of course, there are many other differences; the question is to what degree growth and age distributions alone _might_ account for differences in Gini index, even if there were no other factors.

# %% [markdown]
# ## Competitive vs Wage Models

# %% [markdown]
# We have had a wage-based model in which wages just went up independent of skill.
#
# We've also had a purely competitive "investment" model in which people multiplied their wealth through skill.
#
# - What is the effect of taxation and redistribution in either model?
# - Can you come up with a good mixed model?
